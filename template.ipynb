# %% [markdown]
# ## **Uncertainty Engine SDK Template**

# %% [markdown]
# #### **Import Relevant Libraries**

# %%
from dotenv import load_dotenv
import os
import pandas as pd
import numpy as np

from uncertainty_engine import Client, Environment

# %% [markdown]
# #### **Common UE Classes**

# %%
# Import core UE classes
from uncertainty_engine.graph import Graph
from uncertainty_engine.nodes.workflow import Workflow
from uncertainty_engine.nodes.base import Node

# %% [markdown]
# #### **Establish Connection to the Uncertainty Engine**

# %%
# Ensure .env file contains correct UE credentials and environment conifugurations (if applicable)
load_dotenv()

# Option 1: Standard Environment Set-up

client = Client()
client.authenticate()

#####################################

# Option 2: Custom Environment Set-up

# env=Environment(
#     cognito_user_pool_client_id=os.environ["cognito_user_pool_client_id"],
#     core_api=os.environ["core_api"],
#     region=os.environ["region"],
#     resource_api=os.environ["resource_api"]
# )

# client = Client(env=env)
# client.authenticate()

# %% [markdown]
# #### **Select Relevant Project**

# %%
# Currently, projects must be created via the Uncertainty Engine GUI
PROJECT_NAME = "Personal"
project_id = client.projects.get_project_id_by_name(PROJECT_NAME)

# %% [markdown]
# ##### **If the previous cells have run without error; you are ready to proceed with building workflows with the Uncertainty Engine SDK!**
